# %% [markdown]
# # 02. Preprocess
#
# We preprocess the nvBench dataset in ncNet, based on the EDA result in the previous notebook.
#
# There are two primary columns in the nvBench dataset: nl_queries and vis_query.VQL (SQL + Visualization Attributes).
# It is troublesome to parse VQL. However, ncNet provides a parsed format of VQL, VegaZero.
# So we preprocess the nvBench dataset in ncNet to use VegaZero, instead of the original one.
#
# Our goal is NOT to create a better model for V-NLI but to propose a new UI for data visualization.
# That is, there is no need to use precisely the same dataset as nvBench or ncNet because it's not a must to compare our model with the existing one.
# So, to make experiments easier, we filter out samples containing a broken SQL, Chinese characters, etc.
# Finally, we split the dataset into train / test / validation subsets.
#
# We use this preprocessed dataset to train our models in the following notebooks.

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Define Parameters

# %%
data_dir: str = "../data/"

# %% [markdown]
# ### Load Modules

# %%
import sqlite3

from itertools import product
from pathlib import Path
from random import Random

import numpy as np
import pandas as pd

from sklearn.model_selection import GroupShuffleSplit

from vxnli._vega_zero import VegaZero

# %% [markdown]
# ### Load Dataset

# %%
DATA_DIR: Path = Path(data_dir)
DATABASE_DIR: Path = DATA_DIR.joinpath("datasets/nvBench/database/")
NCNET_DATASET_DIR: Path = DATA_DIR.joinpath("datasets/ncNet/dataset/")
OUTPUT_DIR: Path = DATA_DIR.joinpath("datasets/vxnli-v0/")

# %%
OUTPUT_DIR.mkdir(exist_ok=True)

# %%
ncnet_train_df = pd.read_csv(NCNET_DATASET_DIR.joinpath("dataset_final/train.csv"))
ncnet_test_df = pd.read_csv(NCNET_DATASET_DIR.joinpath("dataset_final/test.csv"))
ncnet_val_df = pd.read_csv(NCNET_DATASET_DIR.joinpath("dataset_final/dev.csv"))

df = pd.concat(
    [
        ncnet_train_df,
        ncnet_test_df,
        ncnet_val_df,
    ],
    ignore_index=True,
)

df
# Out:
#              tvBench_id                            db_id chart hardness  \
# 0      1000@y_name@DESC  customers_and_products_contacts   Bar   Medium
# 1      1000@y_name@DESC  customers_and_products_contacts   Bar   Medium
# 2       2463@x_name@ASC                        network_2   Bar     Easy
# 3       2463@x_name@ASC                        network_2   Bar     Easy
# 4      2545@y_name@DESC                           pets_1   Bar   Medium
# ...                 ...                              ...   ...      ...
# 31583              2911                         swimming   Bar     Easy
# 31584               218              behavior_monitoring   Bar   Medium
# 31585               218              behavior_monitoring   Bar   Medium
# 31586   1761@y_name@ASC                             hr_1   Bar     Hard
# 31587   1761@y_name@ASC                             hr_1   Bar     Hard
#
#                                                    query  \
# 0      Visualize BAR SELECT product_name , COUNT(prod...
# 1      Visualize BAR SELECT product_name , COUNT(prod...
# 2      Visualize BAR SELECT job , min(age) FROM Perso...
# 3      Visualize BAR SELECT job , min(age) FROM Perso...
# 4      Visualize BAR SELECT PetType , avg(pet_age) FR...
# ...                                                  ...
# 31583  Visualize BAR SELECT meter_200 , AVG(ID) FROM ...
# 31584  Visualize BAR SELECT other_details , SUM(month...
# 31585  Visualize BAR SELECT other_details , SUM(month...
# 31586  Visualize BAR SELECT HIRE_DATE , AVG(MANAGER_I...
# 31587  Visualize BAR SELECT HIRE_DATE , AVG(MANAGER_I...
#
#                                                 question  \
# 0      Bar chart x axis product name y axis how many ...
# 1      Bar chart x axis product name y axis how many ...
# 2      how old is the youngest person for each job ? ...
# 3      how old is the youngest person for each job ? ...
# 4      Please give me a bar chart to show the average...
# ...                                                  ...
# 31583  Return a bar chart about the distribution of m...
# 31584  Return a bar chart about the distribution of o...
# 31585  Return a bar chart about the distribution of o...
# 31586  For those employees who was hired before 2002-...
# 31587  For those employees who was hired before 2002-...
#
#                                                vega_zero  \
# 0      mark bar data products encoding x product_name...
# 1      mark bar data products encoding x product_name...
# 2      mark bar data person encoding x job y aggregat...
# 3      mark bar data person encoding x job y aggregat...
# 4      mark bar data pets encoding x pettype y aggreg...
# ...                                                  ...
# 31583  mark bar data swimmer encoding x meter_200 y a...
# 31584  mark bar data student_addresses encoding x oth...
# 31585  mark bar data student_addresses encoding x oth...
# 31586  mark bar data employees encoding x hire_date y...
# 31587  mark bar data employees encoding x hire_date y...
#
#                                        mentioned_columns  \
# 0                                           product_name
# 1                                           product_name
# 2                                           job age name
# 3                                           job age name
# 4                                  pet_age petid pettype
# ...                                                  ...
# 31583  id meter_200 meter_300 meter_700 meter_100 met...
# 31584                       monthly_rental other_details
# 31585                       monthly_rental other_details
# 31586          hire_date manager_id first_name last_name
# 31587          hire_date manager_id first_name last_name
#
#                                         mentioned_values  \
# 0                                                   Sony
# 1                                                   Sony
# 2                                           Zach Bob Dan
# 3                                           Zach Bob Dan
# 4                                                    cat
# ...                                                  ...
# 31583                                                NaN
# 31584                                                NaN
# 31585                                                NaN
# 31586  Luis King Banda Gee Lee Chen Ande Baer Fay Raj...
# 31587  Luis King Banda Gee Lee Chen Ande Baer Fay Raj...
#
#                                           query_template  \
# 0      mark [T] data products encoding x [X] y aggreg...
# 1      mark bar data products encoding x [X] y aggreg...
# 2      mark [T] data person encoding x [X] y aggregat...
# 3      mark bar data person encoding x [X] y aggregat...
# 4      mark [T] data pets encoding x [X] y aggregate ...
# ...                                                  ...
# 31583  mark bar data [D] encoding x [X] y aggregate [...
# 31584  mark [T] data student_addresses encoding x [X]...
# 31585  mark bar data student_addresses encoding x [X]...
# 31586  mark [T] data employees encoding x [X] y aggre...
# 31587  mark bar data employees encoding x [X] y aggre...
#
#                                                   source  \
# 0      <N> Bar chart x axis product name y axis how m...
# 1      <N> Bar chart x axis product name y axis how m...
# 2      <N> how old is the youngest person for each jo...
# 3      <N> how old is the youngest person for each jo...
# 4      <N> Please give me a bar chart to show the ave...
# ...                                                  ...
# 31583  <N> Return a bar chart about the distribution ...
# 31584  <N> Return a bar chart about the distribution ...
# 31585  <N> Return a bar chart about the distribution ...
# 31586  <N> For those employees who was hired before 2...
# 31587  <N> For those employees who was hired before 2...
#
#                                                   labels  \
# 0      mark bar data products encoding x product_name...
# 1      mark bar data products encoding x product_name...
# 2      mark bar data person encoding x job y aggregat...
# 3      mark bar data person encoding x job y aggregat...
# 4      mark bar data pets encoding x pettype y aggreg...
# ...                                                  ...
# 31583  mark bar data swimmer encoding x meter_200 y a...
# 31584  mark bar data student_addresses encoding x oth...
# 31585  mark bar data student_addresses encoding x oth...
# 31586  mark bar data employees encoding x hire_date y...
# 31587  mark bar data employees encoding x hire_date y...
#
#                                              token_types
# 0      nl nl nl nl nl nl nl nl nl nl nl nl nl nl nl n...
# 1      nl nl nl nl nl nl nl nl nl nl nl nl nl nl nl n...
# 2      nl nl nl nl nl nl nl nl nl nl nl nl nl nl nl n...
# 3      nl nl nl nl nl nl nl nl nl nl nl nl nl nl nl n...
# 4      nl nl nl nl nl nl nl nl nl nl nl nl nl nl nl n...
# ...                                                  ...
# 31583  nl nl nl nl nl nl nl nl nl nl nl nl nl nl nl n...
# 31584  nl nl nl nl nl nl nl nl nl nl nl nl nl nl nl n...
# 31585  nl nl nl nl nl nl nl nl nl nl nl nl nl nl nl n...
# 31586  nl nl nl nl nl nl nl nl nl nl nl nl nl nl nl n...
# 31587  nl nl nl nl nl nl nl nl nl nl nl nl nl nl nl n...
#
# [31588 rows x 13 columns]

# %% [markdown]
# ## Preprocess

# %% [markdown]
# ### Remove Unnecessary Columns

# %%
df = df[["db_id", "chart", "hardness", "query", "question", "vega_zero"]]

df
# Out:
#                                  db_id chart hardness  \
# 0      customers_and_products_contacts   Bar   Medium
# 1      customers_and_products_contacts   Bar   Medium
# 2                            network_2   Bar     Easy
# 3                            network_2   Bar     Easy
# 4                               pets_1   Bar   Medium
# ...                                ...   ...      ...
# 31583                         swimming   Bar     Easy
# 31584              behavior_monitoring   Bar   Medium
# 31585              behavior_monitoring   Bar   Medium
# 31586                             hr_1   Bar     Hard
# 31587                             hr_1   Bar     Hard
#
#                                                    query  \
# 0      Visualize BAR SELECT product_name , COUNT(prod...
# 1      Visualize BAR SELECT product_name , COUNT(prod...
# 2      Visualize BAR SELECT job , min(age) FROM Perso...
# 3      Visualize BAR SELECT job , min(age) FROM Perso...
# 4      Visualize BAR SELECT PetType , avg(pet_age) FR...
# ...                                                  ...
# 31583  Visualize BAR SELECT meter_200 , AVG(ID) FROM ...
# 31584  Visualize BAR SELECT other_details , SUM(month...
# 31585  Visualize BAR SELECT other_details , SUM(month...
# 31586  Visualize BAR SELECT HIRE_DATE , AVG(MANAGER_I...
# 31587  Visualize BAR SELECT HIRE_DATE , AVG(MANAGER_I...
#
#                                                 question  \
# 0      Bar chart x axis product name y axis how many ...
# 1      Bar chart x axis product name y axis how many ...
# 2      how old is the youngest person for each job ? ...
# 3      how old is the youngest person for each job ? ...
# 4      Please give me a bar chart to show the average...
# ...                                                  ...
# 31583  Return a bar chart about the distribution of m...
# 31584  Return a bar chart about the distribution of o...
# 31585  Return a bar chart about the distribution of o...
# 31586  For those employees who was hired before 2002-...
# 31587  For those employees who was hired before 2002-...
#
#                                                vega_zero
# 0      mark bar data products encoding x product_name...
# 1      mark bar data products encoding x product_name...
# 2      mark bar data person encoding x job y aggregat...
# 3      mark bar data person encoding x job y aggregat...
# 4      mark bar data pets encoding x pettype y aggreg...
# ...                                                  ...
# 31583  mark bar data swimmer encoding x meter_200 y a...
# 31584  mark bar data student_addresses encoding x oth...
# 31585  mark bar data student_addresses encoding x oth...
# 31586  mark bar data employees encoding x hire_date y...
# 31587  mark bar data employees encoding x hire_date y...
#
# [31588 rows x 6 columns]

# %% [markdown]
# ### Remove Duplicated Rows

# %%
df = df.drop_duplicates()
df = df.reset_index(drop=True)

df
# Out:
#                                  db_id chart    hardness  \
# 0      customers_and_products_contacts   Bar      Medium
# 1                            network_2   Bar        Easy
# 2                               pets_1   Bar      Medium
# 3                    products_for_hire   Bar  Extra Hard
# 4                             election   Bar        Easy
# ...                                ...   ...         ...
# 15780             cre_Docs_and_Epenses   Bar      Medium
# 15781                         wrestler   Bar      Medium
# 15782                         swimming   Bar        Easy
# 15783              behavior_monitoring   Bar      Medium
# 15784                             hr_1   Bar        Hard
#
#                                                    query  \
# 0      Visualize BAR SELECT product_name , COUNT(prod...
# 1      Visualize BAR SELECT job , min(age) FROM Perso...
# 2      Visualize BAR SELECT PetType , avg(pet_age) FR...
# 3      Visualize BAR SELECT payment_date , COUNT(paym...
# 4      Visualize BAR SELECT County_name , Population ...
# ...                                                  ...
# 15780  Visualize BAR SELECT Budget_Type_Code , count(...
# 15781  Visualize BAR SELECT Location , COUNT(Location...
# 15782  Visualize BAR SELECT meter_200 , AVG(ID) FROM ...
# 15783  Visualize BAR SELECT other_details , SUM(month...
# 15784  Visualize BAR SELECT HIRE_DATE , AVG(MANAGER_I...
#
#                                                 question  \
# 0      Bar chart x axis product name y axis how many ...
# 1      how old is the youngest person for each job ? ...
# 2      Please give me a bar chart to show the average...
# 3      What are the payment date of the payment with ...
# 4      What are the name and population of each count...
# ...                                                  ...
# 15780  what are the different budget type codes , and...
# 15781  Give the number of locations of all wrestlers ...
# 15782  Return a bar chart about the distribution of m...
# 15783  Return a bar chart about the distribution of o...
# 15784  For those employees who was hired before 2002-...
#
#                                                vega_zero
# 0      mark bar data products encoding x product_name...
# 1      mark bar data person encoding x job y aggregat...
# 2      mark bar data pets encoding x pettype y aggreg...
# 3      mark bar data payments encoding x payment_date...
# 4      mark bar data county encoding x county_name y ...
# ...                                                  ...
# 15780  mark bar data documents_with_expenses encoding...
# 15781  mark bar data wrestler encoding x location y a...
# 15782  mark bar data swimmer encoding x meter_200 y a...
# 15783  mark bar data student_addresses encoding x oth...
# 15784  mark bar data employees encoding x hire_date y...
#
# [15785 rows x 6 columns]

# %% [markdown]
# ### Add SQL Column

# %%
def retrieve_sql_from_query(query: str) -> str:
    # Remove "Visualize CHART_TYPE"
    [_, _, sql] = query.split(" ", maxsplit=2)

    # Remove "BIN ..." because it is not a standard sqlite3 format and raises an error
    [sql, *_] = sql.rsplit("BIN", maxsplit=1)

    return sql


df["SQL"] = df["query"].apply(retrieve_sql_from_query)

df
# Out:
#                                  db_id chart    hardness  \
# 0      customers_and_products_contacts   Bar      Medium
# 1                            network_2   Bar        Easy
# 2                               pets_1   Bar      Medium
# 3                    products_for_hire   Bar  Extra Hard
# 4                             election   Bar        Easy
# ...                                ...   ...         ...
# 15780             cre_Docs_and_Epenses   Bar      Medium
# 15781                         wrestler   Bar      Medium
# 15782                         swimming   Bar        Easy
# 15783              behavior_monitoring   Bar      Medium
# 15784                             hr_1   Bar        Hard
#
#                                                    query  \
# 0      Visualize BAR SELECT product_name , COUNT(prod...
# 1      Visualize BAR SELECT job , min(age) FROM Perso...
# 2      Visualize BAR SELECT PetType , avg(pet_age) FR...
# 3      Visualize BAR SELECT payment_date , COUNT(paym...
# 4      Visualize BAR SELECT County_name , Population ...
# ...                                                  ...
# 15780  Visualize BAR SELECT Budget_Type_Code , count(...
# 15781  Visualize BAR SELECT Location , COUNT(Location...
# 15782  Visualize BAR SELECT meter_200 , AVG(ID) FROM ...
# 15783  Visualize BAR SELECT other_details , SUM(month...
# 15784  Visualize BAR SELECT HIRE_DATE , AVG(MANAGER_I...
#
#                                                 question  \
# 0      Bar chart x axis product name y axis how many ...
# 1      how old is the youngest person for each job ? ...
# 2      Please give me a bar chart to show the average...
# 3      What are the payment date of the payment with ...
# 4      What are the name and population of each count...
# ...                                                  ...
# 15780  what are the different budget type codes , and...
# 15781  Give the number of locations of all wrestlers ...
# 15782  Return a bar chart about the distribution of m...
# 15783  Return a bar chart about the distribution of o...
# 15784  For those employees who was hired before 2002-...
#
#                                                vega_zero  \
# 0      mark bar data products encoding x product_name...
# 1      mark bar data person encoding x job y aggregat...
# 2      mark bar data pets encoding x pettype y aggreg...
# 3      mark bar data payments encoding x payment_date...
# 4      mark bar data county encoding x county_name y ...
# ...                                                  ...
# 15780  mark bar data documents_with_expenses encoding...
# 15781  mark bar data wrestler encoding x location y a...
# 15782  mark bar data swimmer encoding x meter_200 y a...
# 15783  mark bar data student_addresses encoding x oth...
# 15784  mark bar data employees encoding x hire_date y...
#
#                                                      SQL
# 0      SELECT product_name , COUNT(product_name) FROM...
# 1      SELECT job , min(age) FROM Person GROUP BY job...
# 2      SELECT PetType , avg(pet_age) FROM pets GROUP ...
# 3      SELECT payment_date , COUNT(payment_date) FROM...
# 4            SELECT County_name , Population FROM county
# ...                                                  ...
# 15780  SELECT Budget_Type_Code , count(*) FROM Docume...
# 15781  SELECT Location , COUNT(Location) FROM wrestle...
# 15782  SELECT meter_200 , AVG(ID) FROM swimmer GROUP ...
# 15783  SELECT other_details , SUM(monthly_rental) FRO...
# 15784  SELECT HIRE_DATE , AVG(MANAGER_ID) FROM employ...
#
# [15785 rows x 7 columns]

# %% [markdown]
# ### Remove Rows Containing Broken SQLs

# %%
has_sql_error = np.zeros(len(df), dtype=bool)

for i, row in df.iterrows():
    con = row["db_id"]
    con = DATABASE_DIR.joinpath(f"{con}/{con}.sqlite")
    con = sqlite3.connect(con)

    cur = con.cursor()

    try:
        cur.execute(row["SQL"]).fetchall()
    except sqlite3.OperationalError:
        has_sql_error[i] = True
    finally:
        con.close()

df = df[~has_sql_error]

df
# Out:
#                                  db_id chart    hardness  \
# 0      customers_and_products_contacts   Bar      Medium
# 1                            network_2   Bar        Easy
# 2                               pets_1   Bar      Medium
# 3                    products_for_hire   Bar  Extra Hard
# 4                             election   Bar        Easy
# ...                                ...   ...         ...
# 15780             cre_Docs_and_Epenses   Bar      Medium
# 15781                         wrestler   Bar      Medium
# 15782                         swimming   Bar        Easy
# 15783              behavior_monitoring   Bar      Medium
# 15784                             hr_1   Bar        Hard
#
#                                                    query  \
# 0      Visualize BAR SELECT product_name , COUNT(prod...
# 1      Visualize BAR SELECT job , min(age) FROM Perso...
# 2      Visualize BAR SELECT PetType , avg(pet_age) FR...
# 3      Visualize BAR SELECT payment_date , COUNT(paym...
# 4      Visualize BAR SELECT County_name , Population ...
# ...                                                  ...
# 15780  Visualize BAR SELECT Budget_Type_Code , count(...
# 15781  Visualize BAR SELECT Location , COUNT(Location...
# 15782  Visualize BAR SELECT meter_200 , AVG(ID) FROM ...
# 15783  Visualize BAR SELECT other_details , SUM(month...
# 15784  Visualize BAR SELECT HIRE_DATE , AVG(MANAGER_I...
#
#                                                 question  \
# 0      Bar chart x axis product name y axis how many ...
# 1      how old is the youngest person for each job ? ...
# 2      Please give me a bar chart to show the average...
# 3      What are the payment date of the payment with ...
# 4      What are the name and population of each count...
# ...                                                  ...
# 15780  what are the different budget type codes , and...
# 15781  Give the number of locations of all wrestlers ...
# 15782  Return a bar chart about the distribution of m...
# 15783  Return a bar chart about the distribution of o...
# 15784  For those employees who was hired before 2002-...
#
#                                                vega_zero  \
# 0      mark bar data products encoding x product_name...
# 1      mark bar data person encoding x job y aggregat...
# 2      mark bar data pets encoding x pettype y aggreg...
# 3      mark bar data payments encoding x payment_date...
# 4      mark bar data county encoding x county_name y ...
# ...                                                  ...
# 15780  mark bar data documents_with_expenses encoding...
# 15781  mark bar data wrestler encoding x location y a...
# 15782  mark bar data swimmer encoding x meter_200 y a...
# 15783  mark bar data student_addresses encoding x oth...
# 15784  mark bar data employees encoding x hire_date y...
#
#                                                      SQL
# 0      SELECT product_name , COUNT(product_name) FROM...
# 1      SELECT job , min(age) FROM Person GROUP BY job...
# 2      SELECT PetType , avg(pet_age) FROM pets GROUP ...
# 3      SELECT payment_date , COUNT(payment_date) FROM...
# 4            SELECT County_name , Population FROM county
# ...                                                  ...
# 15780  SELECT Budget_Type_Code , count(*) FROM Docume...
# 15781  SELECT Location , COUNT(Location) FROM wrestle...
# 15782  SELECT meter_200 , AVG(ID) FROM swimmer GROUP ...
# 15783  SELECT other_details , SUM(monthly_rental) FRO...
# 15784  SELECT HIRE_DATE , AVG(MANAGER_ID) FROM employ...
#
# [15761 rows x 7 columns]

# %% [markdown]
# ### Remove Rows Containing Broken Table

# %%
tables = set()

for _, row in df.iterrows():
    db_id = row["db_id"]

    vega_zero = row["vega_zero"]
    vega_zero = VegaZero.from_str(vega_zero)

    table = vega_zero.data

    tables.add((db_id, table))

broken_tables = set()

for db_id, table in tables:
    with sqlite3.connect(DATABASE_DIR.joinpath(f"{db_id}/{db_id}.sqlite")) as con:
        try:
            pd.read_sql(f"SELECT * FROM {table}", con)
        except:
            broken_tables.add((db_id, table))

broken_tables
# Out:
# {('wta_1', 'players')}

# %%
def has_broken_table(row) -> bool:
    db_id = row["db_id"]

    vega_zero = row["vega_zero"]
    vega_zero = VegaZero.from_str(vega_zero)

    table = vega_zero.data

    return (db_id, table) in broken_tables


df = df[~df.apply(has_broken_table, axis=1)]

len(df)
# Out:
# 15731

# %% [markdown]
# ### Replace Apostrophes in Question with Double Quote

# %%
# Copy dataframe to avoid SettingWithCopyWarning
df = df.copy()

df["question"] = df["question"].str.replace("’", '"')
df["question"] = df["question"].str.replace("‘", '"').copy()

df
# Out:
#                                  db_id chart    hardness  \
# 0      customers_and_products_contacts   Bar      Medium
# 1                            network_2   Bar        Easy
# 2                               pets_1   Bar      Medium
# 3                    products_for_hire   Bar  Extra Hard
# 4                             election   Bar        Easy
# ...                                ...   ...         ...
# 15780             cre_Docs_and_Epenses   Bar      Medium
# 15781                         wrestler   Bar      Medium
# 15782                         swimming   Bar        Easy
# 15783              behavior_monitoring   Bar      Medium
# 15784                             hr_1   Bar        Hard
#
#                                                    query  \
# 0      Visualize BAR SELECT product_name , COUNT(prod...
# 1      Visualize BAR SELECT job , min(age) FROM Perso...
# 2      Visualize BAR SELECT PetType , avg(pet_age) FR...
# 3      Visualize BAR SELECT payment_date , COUNT(paym...
# 4      Visualize BAR SELECT County_name , Population ...
# ...                                                  ...
# 15780  Visualize BAR SELECT Budget_Type_Code , count(...
# 15781  Visualize BAR SELECT Location , COUNT(Location...
# 15782  Visualize BAR SELECT meter_200 , AVG(ID) FROM ...
# 15783  Visualize BAR SELECT other_details , SUM(month...
# 15784  Visualize BAR SELECT HIRE_DATE , AVG(MANAGER_I...
#
#                                                 question  \
# 0      Bar chart x axis product name y axis how many ...
# 1      how old is the youngest person for each job ? ...
# 2      Please give me a bar chart to show the average...
# 3      What are the payment date of the payment with ...
# 4      What are the name and population of each count...
# ...                                                  ...
# 15780  what are the different budget type codes , and...
# 15781  Give the number of locations of all wrestlers ...
# 15782  Return a bar chart about the distribution of m...
# 15783  Return a bar chart about the distribution of o...
# 15784  For those employees who was hired before 2002-...
#
#                                                vega_zero  \
# 0      mark bar data products encoding x product_name...
# 1      mark bar data person encoding x job y aggregat...
# 2      mark bar data pets encoding x pettype y aggreg...
# 3      mark bar data payments encoding x payment_date...
# 4      mark bar data county encoding x county_name y ...
# ...                                                  ...
# 15780  mark bar data documents_with_expenses encoding...
# 15781  mark bar data wrestler encoding x location y a...
# 15782  mark bar data swimmer encoding x meter_200 y a...
# 15783  mark bar data student_addresses encoding x oth...
# 15784  mark bar data employees encoding x hire_date y...
#
#                                                      SQL
# 0      SELECT product_name , COUNT(product_name) FROM...
# 1      SELECT job , min(age) FROM Person GROUP BY job...
# 2      SELECT PetType , avg(pet_age) FROM pets GROUP ...
# 3      SELECT payment_date , COUNT(payment_date) FROM...
# 4            SELECT County_name , Population FROM county
# ...                                                  ...
# 15780  SELECT Budget_Type_Code , count(*) FROM Docume...
# 15781  SELECT Location , COUNT(Location) FROM wrestle...
# 15782  SELECT meter_200 , AVG(ID) FROM swimmer GROUP ...
# 15783  SELECT other_details , SUM(monthly_rental) FRO...
# 15784  SELECT HIRE_DATE , AVG(MANAGER_ID) FROM employ...
#
# [15731 rows x 7 columns]

# %% [markdown]
# ### Remove Rows Containing Chinese Characters

# %%
def is_ascii(question: str) -> bool:
    return question.isascii()


# pandas dataframe doesn't have str.isascii method
df = df[df["question"].apply(is_ascii)]

df
# Out:
#                                  db_id chart    hardness  \
# 0      customers_and_products_contacts   Bar      Medium
# 1                            network_2   Bar        Easy
# 2                               pets_1   Bar      Medium
# 3                    products_for_hire   Bar  Extra Hard
# 4                             election   Bar        Easy
# ...                                ...   ...         ...
# 15780             cre_Docs_and_Epenses   Bar      Medium
# 15781                         wrestler   Bar      Medium
# 15782                         swimming   Bar        Easy
# 15783              behavior_monitoring   Bar      Medium
# 15784                             hr_1   Bar        Hard
#
#                                                    query  \
# 0      Visualize BAR SELECT product_name , COUNT(prod...
# 1      Visualize BAR SELECT job , min(age) FROM Perso...
# 2      Visualize BAR SELECT PetType , avg(pet_age) FR...
# 3      Visualize BAR SELECT payment_date , COUNT(paym...
# 4      Visualize BAR SELECT County_name , Population ...
# ...                                                  ...
# 15780  Visualize BAR SELECT Budget_Type_Code , count(...
# 15781  Visualize BAR SELECT Location , COUNT(Location...
# 15782  Visualize BAR SELECT meter_200 , AVG(ID) FROM ...
# 15783  Visualize BAR SELECT other_details , SUM(month...
# 15784  Visualize BAR SELECT HIRE_DATE , AVG(MANAGER_I...
#
#                                                 question  \
# 0      Bar chart x axis product name y axis how many ...
# 1      how old is the youngest person for each job ? ...
# 2      Please give me a bar chart to show the average...
# 3      What are the payment date of the payment with ...
# 4      What are the name and population of each count...
# ...                                                  ...
# 15780  what are the different budget type codes , and...
# 15781  Give the number of locations of all wrestlers ...
# 15782  Return a bar chart about the distribution of m...
# 15783  Return a bar chart about the distribution of o...
# 15784  For those employees who was hired before 2002-...
#
#                                                vega_zero  \
# 0      mark bar data products encoding x product_name...
# 1      mark bar data person encoding x job y aggregat...
# 2      mark bar data pets encoding x pettype y aggreg...
# 3      mark bar data payments encoding x payment_date...
# 4      mark bar data county encoding x county_name y ...
# ...                                                  ...
# 15780  mark bar data documents_with_expenses encoding...
# 15781  mark bar data wrestler encoding x location y a...
# 15782  mark bar data swimmer encoding x meter_200 y a...
# 15783  mark bar data student_addresses encoding x oth...
# 15784  mark bar data employees encoding x hire_date y...
#
#                                                      SQL
# 0      SELECT product_name , COUNT(product_name) FROM...
# 1      SELECT job , min(age) FROM Person GROUP BY job...
# 2      SELECT PetType , avg(pet_age) FROM pets GROUP ...
# 3      SELECT payment_date , COUNT(payment_date) FROM...
# 4            SELECT County_name , Population FROM county
# ...                                                  ...
# 15780  SELECT Budget_Type_Code , count(*) FROM Docume...
# 15781  SELECT Location , COUNT(Location) FROM wrestle...
# 15782  SELECT meter_200 , AVG(ID) FROM swimmer GROUP ...
# 15783  SELECT other_details , SUM(monthly_rental) FRO...
# 15784  SELECT HIRE_DATE , AVG(MANAGER_ID) FROM employ...
#
# [15726 rows x 7 columns]

# %% [markdown]
# ### Remove Commas

# %%
# Copy dataframe to avoid SettingWithCopyWarning
df = df.copy()

df["vega_zero"] = df["vega_zero"].str.replace(" , ", " ")

df
# Out:
#                                  db_id chart    hardness  \
# 0      customers_and_products_contacts   Bar      Medium
# 1                            network_2   Bar        Easy
# 2                               pets_1   Bar      Medium
# 3                    products_for_hire   Bar  Extra Hard
# 4                             election   Bar        Easy
# ...                                ...   ...         ...
# 15780             cre_Docs_and_Epenses   Bar      Medium
# 15781                         wrestler   Bar      Medium
# 15782                         swimming   Bar        Easy
# 15783              behavior_monitoring   Bar      Medium
# 15784                             hr_1   Bar        Hard
#
#                                                    query  \
# 0      Visualize BAR SELECT product_name , COUNT(prod...
# 1      Visualize BAR SELECT job , min(age) FROM Perso...
# 2      Visualize BAR SELECT PetType , avg(pet_age) FR...
# 3      Visualize BAR SELECT payment_date , COUNT(paym...
# 4      Visualize BAR SELECT County_name , Population ...
# ...                                                  ...
# 15780  Visualize BAR SELECT Budget_Type_Code , count(...
# 15781  Visualize BAR SELECT Location , COUNT(Location...
# 15782  Visualize BAR SELECT meter_200 , AVG(ID) FROM ...
# 15783  Visualize BAR SELECT other_details , SUM(month...
# 15784  Visualize BAR SELECT HIRE_DATE , AVG(MANAGER_I...
#
#                                                 question  \
# 0      Bar chart x axis product name y axis how many ...
# 1      how old is the youngest person for each job ? ...
# 2      Please give me a bar chart to show the average...
# 3      What are the payment date of the payment with ...
# 4      What are the name and population of each count...
# ...                                                  ...
# 15780  what are the different budget type codes , and...
# 15781  Give the number of locations of all wrestlers ...
# 15782  Return a bar chart about the distribution of m...
# 15783  Return a bar chart about the distribution of o...
# 15784  For those employees who was hired before 2002-...
#
#                                                vega_zero  \
# 0      mark bar data products encoding x product_name...
# 1      mark bar data person encoding x job y aggregat...
# 2      mark bar data pets encoding x pettype y aggreg...
# 3      mark bar data payments encoding x payment_date...
# 4      mark bar data county encoding x county_name y ...
# ...                                                  ...
# 15780  mark bar data documents_with_expenses encoding...
# 15781  mark bar data wrestler encoding x location y a...
# 15782  mark bar data swimmer encoding x meter_200 y a...
# 15783  mark bar data student_addresses encoding x oth...
# 15784  mark bar data employees encoding x hire_date y...
#
#                                                      SQL
# 0      SELECT product_name , COUNT(product_name) FROM...
# 1      SELECT job , min(age) FROM Person GROUP BY job...
# 2      SELECT PetType , avg(pet_age) FROM pets GROUP ...
# 3      SELECT payment_date , COUNT(payment_date) FROM...
# 4            SELECT County_name , Population FROM county
# ...                                                  ...
# 15780  SELECT Budget_Type_Code , count(*) FROM Docume...
# 15781  SELECT Location , COUNT(Location) FROM wrestle...
# 15782  SELECT meter_200 , AVG(ID) FROM swimmer GROUP ...
# 15783  SELECT other_details , SUM(monthly_rental) FRO...
# 15784  SELECT HIRE_DATE , AVG(MANAGER_ID) FROM employ...
#
# [15726 rows x 7 columns]

# %% [markdown]
# ### Add Table Column

# %%
df["table"] = df["vega_zero"].apply(lambda x: VegaZero.from_str(x).data)

df
# Out:
#                                  db_id chart    hardness  \
# 0      customers_and_products_contacts   Bar      Medium
# 1                            network_2   Bar        Easy
# 2                               pets_1   Bar      Medium
# 3                    products_for_hire   Bar  Extra Hard
# 4                             election   Bar        Easy
# ...                                ...   ...         ...
# 15780             cre_Docs_and_Epenses   Bar      Medium
# 15781                         wrestler   Bar      Medium
# 15782                         swimming   Bar        Easy
# 15783              behavior_monitoring   Bar      Medium
# 15784                             hr_1   Bar        Hard
#
#                                                    query  \
# 0      Visualize BAR SELECT product_name , COUNT(prod...
# 1      Visualize BAR SELECT job , min(age) FROM Perso...
# 2      Visualize BAR SELECT PetType , avg(pet_age) FR...
# 3      Visualize BAR SELECT payment_date , COUNT(paym...
# 4      Visualize BAR SELECT County_name , Population ...
# ...                                                  ...
# 15780  Visualize BAR SELECT Budget_Type_Code , count(...
# 15781  Visualize BAR SELECT Location , COUNT(Location...
# 15782  Visualize BAR SELECT meter_200 , AVG(ID) FROM ...
# 15783  Visualize BAR SELECT other_details , SUM(month...
# 15784  Visualize BAR SELECT HIRE_DATE , AVG(MANAGER_I...
#
#                                                 question  \
# 0      Bar chart x axis product name y axis how many ...
# 1      how old is the youngest person for each job ? ...
# 2      Please give me a bar chart to show the average...
# 3      What are the payment date of the payment with ...
# 4      What are the name and population of each count...
# ...                                                  ...
# 15780  what are the different budget type codes , and...
# 15781  Give the number of locations of all wrestlers ...
# 15782  Return a bar chart about the distribution of m...
# 15783  Return a bar chart about the distribution of o...
# 15784  For those employees who was hired before 2002-...
#
#                                                vega_zero  \
# 0      mark bar data products encoding x product_name...
# 1      mark bar data person encoding x job y aggregat...
# 2      mark bar data pets encoding x pettype y aggreg...
# 3      mark bar data payments encoding x payment_date...
# 4      mark bar data county encoding x county_name y ...
# ...                                                  ...
# 15780  mark bar data documents_with_expenses encoding...
# 15781  mark bar data wrestler encoding x location y a...
# 15782  mark bar data swimmer encoding x meter_200 y a...
# 15783  mark bar data student_addresses encoding x oth...
# 15784  mark bar data employees encoding x hire_date y...
#
#                                                      SQL  \
# 0      SELECT product_name , COUNT(product_name) FROM...
# 1      SELECT job , min(age) FROM Person GROUP BY job...
# 2      SELECT PetType , avg(pet_age) FROM pets GROUP ...
# 3      SELECT payment_date , COUNT(payment_date) FROM...
# 4            SELECT County_name , Population FROM county
# ...                                                  ...
# 15780  SELECT Budget_Type_Code , count(*) FROM Docume...
# 15781  SELECT Location , COUNT(Location) FROM wrestle...
# 15782  SELECT meter_200 , AVG(ID) FROM swimmer GROUP ...
# 15783  SELECT other_details , SUM(monthly_rental) FRO...
# 15784  SELECT HIRE_DATE , AVG(MANAGER_ID) FROM employ...
#
#                          table
# 0                     products
# 1                       person
# 2                         pets
# 3                     payments
# 4                       county
# ...                        ...
# 15780  documents_with_expenses
# 15781                 wrestler
# 15782                  swimmer
# 15783        student_addresses
# 15784                employees
#
# [15726 rows x 8 columns]

# %% [markdown]
# ### Remove Data Attribute from VegaZero
#
# We assume a tabular data is provided as a pandas dataframe.
# So we don't use the data attribute of VegaZero in the prediction.

# %%
def remove_data_attr(vega_zero_str: str) -> str:
    vega_zero = VegaZero.from_str(vega_zero_str)

    vega_zero.data = None

    return str(vega_zero)


df["vega_zero"] = df["vega_zero"].apply(remove_data_attr)

df
# Out:
#                                  db_id chart    hardness  \
# 0      customers_and_products_contacts   Bar      Medium
# 1                            network_2   Bar        Easy
# 2                               pets_1   Bar      Medium
# 3                    products_for_hire   Bar  Extra Hard
# 4                             election   Bar        Easy
# ...                                ...   ...         ...
# 15780             cre_Docs_and_Epenses   Bar      Medium
# 15781                         wrestler   Bar      Medium
# 15782                         swimming   Bar        Easy
# 15783              behavior_monitoring   Bar      Medium
# 15784                             hr_1   Bar        Hard
#
#                                                    query  \
# 0      Visualize BAR SELECT product_name , COUNT(prod...
# 1      Visualize BAR SELECT job , min(age) FROM Perso...
# 2      Visualize BAR SELECT PetType , avg(pet_age) FR...
# 3      Visualize BAR SELECT payment_date , COUNT(paym...
# 4      Visualize BAR SELECT County_name , Population ...
# ...                                                  ...
# 15780  Visualize BAR SELECT Budget_Type_Code , count(...
# 15781  Visualize BAR SELECT Location , COUNT(Location...
# 15782  Visualize BAR SELECT meter_200 , AVG(ID) FROM ...
# 15783  Visualize BAR SELECT other_details , SUM(month...
# 15784  Visualize BAR SELECT HIRE_DATE , AVG(MANAGER_I...
#
#                                                 question  \
# 0      Bar chart x axis product name y axis how many ...
# 1      how old is the youngest person for each job ? ...
# 2      Please give me a bar chart to show the average...
# 3      What are the payment date of the payment with ...
# 4      What are the name and population of each count...
# ...                                                  ...
# 15780  what are the different budget type codes , and...
# 15781  Give the number of locations of all wrestlers ...
# 15782  Return a bar chart about the distribution of m...
# 15783  Return a bar chart about the distribution of o...
# 15784  For those employees who was hired before 2002-...
#
#                                                vega_zero  \
# 0      mark bar encoding x product_name y aggregate c...
# 1      mark bar encoding x job y aggregate min age tr...
# 2      mark bar encoding x pettype y aggregate mean p...
# 3      mark bar encoding x payment_date y aggregate c...
# 4      mark bar encoding x county_name y aggregate no...
# ...                                                  ...
# 15780  mark bar encoding x budget_type_code y aggrega...
# 15781  mark bar encoding x location y aggregate count...
# 15782  mark bar encoding x meter_200 y aggregate mean...
# 15783  mark bar encoding x other_details y aggregate ...
# 15784  mark bar encoding x hire_date y aggregate mean...
#
#                                                      SQL  \
# 0      SELECT product_name , COUNT(product_name) FROM...
# 1      SELECT job , min(age) FROM Person GROUP BY job...
# 2      SELECT PetType , avg(pet_age) FROM pets GROUP ...
# 3      SELECT payment_date , COUNT(payment_date) FROM...
# 4            SELECT County_name , Population FROM county
# ...                                                  ...
# 15780  SELECT Budget_Type_Code , count(*) FROM Docume...
# 15781  SELECT Location , COUNT(Location) FROM wrestle...
# 15782  SELECT meter_200 , AVG(ID) FROM swimmer GROUP ...
# 15783  SELECT other_details , SUM(monthly_rental) FRO...
# 15784  SELECT HIRE_DATE , AVG(MANAGER_ID) FROM employ...
#
#                          table
# 0                     products
# 1                       person
# 2                         pets
# 3                     payments
# 4                       county
# ...                        ...
# 15780  documents_with_expenses
# 15781                 wrestler
# 15782                  swimmer
# 15783        student_addresses
# 15784                employees
#
# [15726 rows x 8 columns]

# %% [markdown]
# ### Replace Single Quote with Double Quote

# %%
# Copy dataframe to avoid SettingWithCopyWarning
df = df.copy()

df["vega_zero"] = df["vega_zero"].str.replace("'", '"')

df
# Out:
#                                  db_id chart    hardness  \
# 0      customers_and_products_contacts   Bar      Medium
# 1                            network_2   Bar        Easy
# 2                               pets_1   Bar      Medium
# 3                    products_for_hire   Bar  Extra Hard
# 4                             election   Bar        Easy
# ...                                ...   ...         ...
# 15780             cre_Docs_and_Epenses   Bar      Medium
# 15781                         wrestler   Bar      Medium
# 15782                         swimming   Bar        Easy
# 15783              behavior_monitoring   Bar      Medium
# 15784                             hr_1   Bar        Hard
#
#                                                    query  \
# 0      Visualize BAR SELECT product_name , COUNT(prod...
# 1      Visualize BAR SELECT job , min(age) FROM Perso...
# 2      Visualize BAR SELECT PetType , avg(pet_age) FR...
# 3      Visualize BAR SELECT payment_date , COUNT(paym...
# 4      Visualize BAR SELECT County_name , Population ...
# ...                                                  ...
# 15780  Visualize BAR SELECT Budget_Type_Code , count(...
# 15781  Visualize BAR SELECT Location , COUNT(Location...
# 15782  Visualize BAR SELECT meter_200 , AVG(ID) FROM ...
# 15783  Visualize BAR SELECT other_details , SUM(month...
# 15784  Visualize BAR SELECT HIRE_DATE , AVG(MANAGER_I...
#
#                                                 question  \
# 0      Bar chart x axis product name y axis how many ...
# 1      how old is the youngest person for each job ? ...
# 2      Please give me a bar chart to show the average...
# 3      What are the payment date of the payment with ...
# 4      What are the name and population of each count...
# ...                                                  ...
# 15780  what are the different budget type codes , and...
# 15781  Give the number of locations of all wrestlers ...
# 15782  Return a bar chart about the distribution of m...
# 15783  Return a bar chart about the distribution of o...
# 15784  For those employees who was hired before 2002-...
#
#                                                vega_zero  \
# 0      mark bar encoding x product_name y aggregate c...
# 1      mark bar encoding x job y aggregate min age tr...
# 2      mark bar encoding x pettype y aggregate mean p...
# 3      mark bar encoding x payment_date y aggregate c...
# 4      mark bar encoding x county_name y aggregate no...
# ...                                                  ...
# 15780  mark bar encoding x budget_type_code y aggrega...
# 15781  mark bar encoding x location y aggregate count...
# 15782  mark bar encoding x meter_200 y aggregate mean...
# 15783  mark bar encoding x other_details y aggregate ...
# 15784  mark bar encoding x hire_date y aggregate mean...
#
#                                                      SQL  \
# 0      SELECT product_name , COUNT(product_name) FROM...
# 1      SELECT job , min(age) FROM Person GROUP BY job...
# 2      SELECT PetType , avg(pet_age) FROM pets GROUP ...
# 3      SELECT payment_date , COUNT(payment_date) FROM...
# 4            SELECT County_name , Population FROM county
# ...                                                  ...
# 15780  SELECT Budget_Type_Code , count(*) FROM Docume...
# 15781  SELECT Location , COUNT(Location) FROM wrestle...
# 15782  SELECT meter_200 , AVG(ID) FROM swimmer GROUP ...
# 15783  SELECT other_details , SUM(monthly_rental) FRO...
# 15784  SELECT HIRE_DATE , AVG(MANAGER_ID) FROM employ...
#
#                          table
# 0                     products
# 1                       person
# 2                         pets
# 3                     payments
# 4                       county
# ...                        ...
# 15780  documents_with_expenses
# 15781                 wrestler
# 15782                  swimmer
# 15783        student_addresses
# 15784                employees
#
# [15726 rows x 8 columns]

# %% [markdown]
# ### Replace Questions with Lower Case
#
# In VegaZero provided by the ncNet authors, all of characters are lower cased.
# It's ok to fix them with the actual cases, however, it's a bit time consuming.
# Moreover, if we unify the cases, we can improve the model accuracy, and avoid unnecessary errors in our final user study.
#
# Again, this study's purpose is to compare V-XNLI with V-NLI.

# %%
df["question"] = df["question"].str.lower()

df
# Out:
#                                  db_id chart    hardness  \
# 0      customers_and_products_contacts   Bar      Medium
# 1                            network_2   Bar        Easy
# 2                               pets_1   Bar      Medium
# 3                    products_for_hire   Bar  Extra Hard
# 4                             election   Bar        Easy
# ...                                ...   ...         ...
# 15780             cre_Docs_and_Epenses   Bar      Medium
# 15781                         wrestler   Bar      Medium
# 15782                         swimming   Bar        Easy
# 15783              behavior_monitoring   Bar      Medium
# 15784                             hr_1   Bar        Hard
#
#                                                    query  \
# 0      Visualize BAR SELECT product_name , COUNT(prod...
# 1      Visualize BAR SELECT job , min(age) FROM Perso...
# 2      Visualize BAR SELECT PetType , avg(pet_age) FR...
# 3      Visualize BAR SELECT payment_date , COUNT(paym...
# 4      Visualize BAR SELECT County_name , Population ...
# ...                                                  ...
# 15780  Visualize BAR SELECT Budget_Type_Code , count(...
# 15781  Visualize BAR SELECT Location , COUNT(Location...
# 15782  Visualize BAR SELECT meter_200 , AVG(ID) FROM ...
# 15783  Visualize BAR SELECT other_details , SUM(month...
# 15784  Visualize BAR SELECT HIRE_DATE , AVG(MANAGER_I...
#
#                                                 question  \
# 0      bar chart x axis product name y axis how many ...
# 1      how old is the youngest person for each job ? ...
# 2      please give me a bar chart to show the average...
# 3      what are the payment date of the payment with ...
# 4      what are the name and population of each count...
# ...                                                  ...
# 15780  what are the different budget type codes , and...
# 15781  give the number of locations of all wrestlers ...
# 15782  return a bar chart about the distribution of m...
# 15783  return a bar chart about the distribution of o...
# 15784  for those employees who was hired before 2002-...
#
#                                                vega_zero  \
# 0      mark bar encoding x product_name y aggregate c...
# 1      mark bar encoding x job y aggregate min age tr...
# 2      mark bar encoding x pettype y aggregate mean p...
# 3      mark bar encoding x payment_date y aggregate c...
# 4      mark bar encoding x county_name y aggregate no...
# ...                                                  ...
# 15780  mark bar encoding x budget_type_code y aggrega...
# 15781  mark bar encoding x location y aggregate count...
# 15782  mark bar encoding x meter_200 y aggregate mean...
# 15783  mark bar encoding x other_details y aggregate ...
# 15784  mark bar encoding x hire_date y aggregate mean...
#
#                                                      SQL  \
# 0      SELECT product_name , COUNT(product_name) FROM...
# 1      SELECT job , min(age) FROM Person GROUP BY job...
# 2      SELECT PetType , avg(pet_age) FROM pets GROUP ...
# 3      SELECT payment_date , COUNT(payment_date) FROM...
# 4            SELECT County_name , Population FROM county
# ...                                                  ...
# 15780  SELECT Budget_Type_Code , count(*) FROM Docume...
# 15781  SELECT Location , COUNT(Location) FROM wrestle...
# 15782  SELECT meter_200 , AVG(ID) FROM swimmer GROUP ...
# 15783  SELECT other_details , SUM(monthly_rental) FRO...
# 15784  SELECT HIRE_DATE , AVG(MANAGER_ID) FROM employ...
#
#                          table
# 0                     products
# 1                       person
# 2                         pets
# 3                     payments
# 4                       county
# ...                        ...
# 15780  documents_with_expenses
# 15781                 wrestler
# 15782                  swimmer
# 15783        student_addresses
# 15784                employees
#
# [15726 rows x 8 columns]

# %% [markdown]
# ## Split Dataset
#
# We split the dataset into train, test and validation subsets (Train : Test : Validate = 8 : 1 : 1).
#
# We use sklearn's GroupShuffleSplit (grouped by db_id column) to avoid data leakage.
# Without this, the trained model knows the database contents beforehand.
# It increases the accuracy of known tables, but decreases the accuracy of unknown tables.
# The ncNet authors trains their model with the table content leaked data, however, we avoid it to consider the real world usage.
#
# It might be better to spare more samples for the train dataset, however, the number of databases are not that large (141) while the sample size is huge.
# We use GroupShuffleSplit, so the number of databases are also split into 8 : 1 : 1.

# %% [markdown]
# ### Split Dataset with GroupShuffleSplit
#
# With GroupShuffleSplit, the numbers of db_id are 8 : 1 : 1, but the dataset sizes are not guaranteed to be 8 : 1 : 1.
# However, the actual sizes happen to be almost 8 : 1 : 1 (12798 : 1543 : 1385).

# %%
gss = GroupShuffleSplit(n_splits=1, train_size=0.8, random_state=123)

for train_idx, test_idx in gss.split(df, groups=df["db_id"]):
    train_df, test_df = df.iloc[train_idx, :], df.iloc[test_idx, :]

gss = GroupShuffleSplit(n_splits=1, test_size=0.5, random_state=123)

for val_idx, test_idx in gss.split(test_df, groups=test_df["db_id"]):
    test_df, val_df = (
        test_df.iloc[test_idx, :],
        test_df.iloc[val_idx, :],
    )

train_df = train_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)
val_df = val_df.reset_index(drop=True)

# %%
train_df
# Out:
#                                  db_id    chart    hardness  \
# 0      customers_and_products_contacts      Bar      Medium
# 1                            network_2      Bar        Easy
# 2                               pets_1      Bar      Medium
# 3                    products_for_hire      Bar  Extra Hard
# 4                             election      Bar        Easy
# ...                                ...      ...         ...
# 12793                             hr_1  Scatter      Medium
# 12794             cre_Docs_and_Epenses      Bar      Medium
# 12795                         wrestler      Bar      Medium
# 12796                         swimming      Bar        Easy
# 12797                             hr_1      Bar        Hard
#
#                                                    query  \
# 0      Visualize BAR SELECT product_name , COUNT(prod...
# 1      Visualize BAR SELECT job , min(age) FROM Perso...
# 2      Visualize BAR SELECT PetType , avg(pet_age) FR...
# 3      Visualize BAR SELECT payment_date , COUNT(paym...
# 4      Visualize BAR SELECT County_name , Population ...
# ...                                                  ...
# 12793  Visualize SCATTER SELECT COMMISSION_PCT , DEPA...
# 12794  Visualize BAR SELECT Budget_Type_Code , count(...
# 12795  Visualize BAR SELECT Location , COUNT(Location...
# 12796  Visualize BAR SELECT meter_200 , AVG(ID) FROM ...
# 12797  Visualize BAR SELECT HIRE_DATE , AVG(MANAGER_I...
#
#                                                 question  \
# 0      bar chart x axis product name y axis how many ...
# 1      how old is the youngest person for each job ? ...
# 2      please give me a bar chart to show the average...
# 3      what are the payment date of the payment with ...
# 4      what are the name and population of each count...
# ...                                                  ...
# 12793  for those employees whose salary is in the ran...
# 12794  what are the different budget type codes , and...
# 12795  give the number of locations of all wrestlers ...
# 12796  return a bar chart about the distribution of m...
# 12797  for those employees who was hired before 2002-...
#
#                                                vega_zero  \
# 0      mark bar encoding x product_name y aggregate c...
# 1      mark bar encoding x job y aggregate min age tr...
# 2      mark bar encoding x pettype y aggregate mean p...
# 3      mark bar encoding x payment_date y aggregate c...
# 4      mark bar encoding x county_name y aggregate no...
# ...                                                  ...
# 12793  mark point encoding x commission_pct y aggrega...
# 12794  mark bar encoding x budget_type_code y aggrega...
# 12795  mark bar encoding x location y aggregate count...
# 12796  mark bar encoding x meter_200 y aggregate mean...
# 12797  mark bar encoding x hire_date y aggregate mean...
#
#                                                      SQL  \
# 0      SELECT product_name , COUNT(product_name) FROM...
# 1      SELECT job , min(age) FROM Person GROUP BY job...
# 2      SELECT PetType , avg(pet_age) FROM pets GROUP ...
# 3      SELECT payment_date , COUNT(payment_date) FROM...
# 4            SELECT County_name , Population FROM county
# ...                                                  ...
# 12793  SELECT COMMISSION_PCT , DEPARTMENT_ID FROM emp...
# 12794  SELECT Budget_Type_Code , count(*) FROM Docume...
# 12795  SELECT Location , COUNT(Location) FROM wrestle...
# 12796  SELECT meter_200 , AVG(ID) FROM swimmer GROUP ...
# 12797  SELECT HIRE_DATE , AVG(MANAGER_ID) FROM employ...
#
#                          table
# 0                     products
# 1                       person
# 2                         pets
# 3                     payments
# 4                       county
# ...                        ...
# 12793                employees
# 12794  documents_with_expenses
# 12795                 wrestler
# 12796                  swimmer
# 12797                employees
#
# [12798 rows x 8 columns]

# %%
test_df
# Out:
#                       db_id chart hardness  \
# 0                    cinema   Bar   Medium
# 1                     wta_1   Bar   Medium
# 2            candidate_poll   Bar     Easy
# 3            candidate_poll   Bar   Medium
# 4       behavior_monitoring   Bar   Medium
# ...                     ...   ...      ...
# 1538  local_govt_in_alabama   Pie     Easy
# 1539            riding_club   Bar   Medium
# 1540          store_product   Pie     Easy
# 1541         candidate_poll   Bar     Easy
# 1542    behavior_monitoring   Bar   Medium
#
#                                                   query  \
# 0     Visualize BAR SELECT Openning_year , COUNT(Ope...
# 1     Visualize BAR SELECT year , count(*) FROM matc...
# 2     Visualize BAR SELECT Sex , min(weight) FROM pe...
# 3     Visualize BAR SELECT Sex , AVG(Weight) FROM pe...
# 4     Visualize BAR SELECT date_address_from , COUNT...
# ...                                                 ...
# 1538  Visualize PIE SELECT Event_Details , COUNT(Eve...
# 1539  Visualize BAR SELECT Occupation , COUNT(Occupa...
# 1540  Visualize PIE SELECT Type , count(*) FROM stor...
# 1541  Visualize BAR SELECT Name , Weight FROM people...
# 1542  Visualize BAR SELECT other_details , SUM(month...
#
#                                                question  \
# 0     give me a bar chart showing the number of cine...
# 1     find the number of matches happened in each ye...
# 2     what is the minimum weights for people of each...
# 3     show me the average of weight by sex in a hist...
# 4     visualize a bar chart about the distribution o...
# ...                                                 ...
# 1538  group and count details for the events using a...
# 1539  bar chart x axis occupation y axis how many oc...
# 1540  for each type of store , how many of them are ...
# 1541  return a bar chart about the distribution of n...
# 1542  return a bar chart about the distribution of o...
#
#                                               vega_zero  \
# 0     mark bar encoding x openning_year y aggregate ...
# 1     mark bar encoding x year y aggregate count yea...
# 2     mark bar encoding x sex y aggregate min weight...
# 3     mark bar encoding x sex y aggregate mean weigh...
# 4     mark bar encoding x date_address_from y aggreg...
# ...                                                 ...
# 1538  mark arc encoding x event_details y aggregate ...
# 1539  mark bar encoding x occupation y aggregate cou...
# 1540  mark arc encoding x type y aggregate count typ...
# 1541  mark bar encoding x name y aggregate none weig...
# 1542  mark bar encoding x other_details y aggregate ...
#
#                                                     SQL              table
# 0     SELECT Openning_year , COUNT(Openning_year) FR...             cinema
# 1     SELECT year , count(*) FROM matches GROUP BY Y...            matches
# 2     SELECT Sex , min(weight) FROM people GROUP BY ...             people
# 3     SELECT Sex , AVG(Weight) FROM people GROUP BY ...             people
# 4     SELECT date_address_from , COUNT(date_address_...  student_addresses
# ...                                                 ...                ...
# 1538  SELECT Event_Details , COUNT(Event_Details) FR...             events
# 1539  SELECT Occupation , COUNT(Occupation) FROM pla...             player
# 1540    SELECT Type , count(*) FROM store GROUP BY TYPE              store
# 1541  SELECT Name , Weight FROM people ORDER BY Name...             people
# 1542  SELECT other_details , SUM(monthly_rental) FRO...  student_addresses
#
# [1543 rows x 8 columns]

# %%
val_df
# Out:
#                     db_id          chart    hardness  \
# 0               college_1            Bar      Medium
# 1             game_injury  Grouping Line        Hard
# 2     cre_Doc_Tracking_DB  Grouping Line  Extra Hard
# 3        department_store            Bar      Medium
# 4               college_1        Scatter        Easy
# ...                   ...            ...         ...
# 1380       school_finance            Bar      Medium
# 1381  cre_Doc_Tracking_DB    Stacked Bar        Hard
# 1382  cre_Doc_Tracking_DB            Bar      Medium
# 1383  cre_Doc_Tracking_DB            Bar        Easy
# 1384  cre_Doc_Tracking_DB            Bar      Medium
#
#                                                   query  \
# 0     Visualize BAR SELECT CRS_CODE , count(*) FROM ...
# 1     Visualize LINE SELECT Season , COUNT(Season) F...
# 2     Visualize LINE SELECT Date_in_Locaton_To , COU...
# 3     Visualize BAR SELECT payment_method_code , cou...
# 4     Visualize SCATTER SELECT max(stu_gpa) , avg(st...
# ...                                                 ...
# 1380  Visualize BAR SELECT County , count(*) FROM sc...
# 1381  Visualize BAR SELECT Date_in_Locaton_To , COUN...
# 1382  Visualize BAR SELECT Location_Code , count(*) ...
# 1383  Visualize BAR SELECT Location_Code , count(*) ...
# 1384  Visualize BAR SELECT Location_Code , count(*) ...
#
#                                                question  \
# 0     visualize a bar chart for how many sections do...
# 1     list the number of games in each season and gr...
# 2     show the number of documents in different endi...
# 3     for each payment method , return how many cust...
# 4     find the relationship between maximum and aver...
# ...                                                 ...
# 1380  draw a bar chart of county versus the total nu...
# 1381  stacked bar of date in locaton to and the numb...
# 1382  show the location codes and the number of docu...
# 1383  what is the code of each location and the numb...
# 1384  what is the code of each location and the numb...
#
#                                               vega_zero  \
# 0     mark bar encoding x crs_code y aggregate count...
# 1     mark line encoding x season y aggregate count ...
# 2     mark line encoding x date_in_locaton_to y aggr...
# 3     mark bar encoding x payment_method_code y aggr...
# 4     mark point encoding x max(stu_gpa) y aggregate...
# ...                                                 ...
# 1380  mark bar encoding x county y aggregate count c...
# 1381  mark bar encoding x date_in_locaton_to y aggre...
# 1382  mark bar encoding x location_code y aggregate ...
# 1383  mark bar encoding x location_code y aggregate ...
# 1384  mark bar encoding x location_code y aggregate ...
#
#                                                     SQL               table
# 0     SELECT CRS_CODE , count(*) FROM CLASS GROUP BY...               class
# 1     SELECT Season , COUNT(Season) FROM game GROUP ...                game
# 2     SELECT Date_in_Locaton_To , COUNT(Date_in_Loca...  document_locations
# 3     SELECT payment_method_code , count(*) FROM cus...           customers
# 4     SELECT max(stu_gpa) , avg(stu_gpa) FROM studen...             student
# ...                                                 ...                 ...
# 1380  SELECT County , count(*) FROM school GROUP BY ...              school
# 1381  SELECT Date_in_Locaton_To , COUNT(Date_in_Loca...  document_locations
# 1382  SELECT Location_Code , count(*) FROM Document_...  document_locations
# 1383  SELECT Location_Code , count(*) FROM Document_...  document_locations
# 1384  SELECT Location_Code , count(*) FROM Document_...  document_locations
#
# [1385 rows x 8 columns]

# %%
train_df.to_csv(OUTPUT_DIR.joinpath("train.csv"), index=False)
test_df.to_csv(OUTPUT_DIR.joinpath("test.csv"), index=False)
val_df.to_csv(OUTPUT_DIR.joinpath("val.csv"), index=False)

# %% [markdown]
# ## Analytics

# %%
df["hardness"].value_counts()
# Out:
# Medium        6931
# Easy          5582
# Hard          1834
# Extra Hard    1379
# Name: hardness, dtype: int64

# %%
df["chart"].value_counts()
# Out:
# Bar                 11592
# Pie                  1124
# Line                 1078
# Scatter               722
# Stacked Bar           624
# Grouping Scatter      377
# Grouping Line         209
# Name: chart, dtype: int64

# %%
# Check if the database subsets don't have the same databases (just in case)

train_df_unique_db_ids = set(train_df["db_id"].unique())
test_df_unique_db_ids = set(test_df["db_id"].unique())
val_df_unique_db_ids = set(val_df["db_id"].unique())

assert len(train_df_unique_db_ids & test_df_unique_db_ids & val_df_unique_db_ids) == 0

# The ratio of databases
len(train_df_unique_db_ids), len(test_df_unique_db_ids), len(val_df_unique_db_ids)
# Out:
# (112, 15, 14)

# %%
# The number of chart is not that balanced
# However, it cannot be helped to some extent because the number of examples in each database is pretty imbalanced
pd.concat(
    [
        train_df["chart"].value_counts().rename("train"),
        val_df["chart"].value_counts().rename("val"),
        test_df["chart"].value_counts().rename("test"),
    ],
    axis=1,
)
# Out:
#                   train  val  test
# Bar                9600  946  1046
# Pie                 887  148    89
# Line                837  113   128
# Scatter             557   31   134
# Stacked Bar         480   65    79
# Grouping Scatter    322   15    40
# Grouping Line       115   67    27

# %%
# Same as the above comment
pd.concat(
    [
        train_df["hardness"].value_counts().rename("train"),
        val_df["hardness"].value_counts().rename("val"),
        test_df["hardness"].value_counts().rename("test"),
    ],
    axis=1,
)
# Out:
#             train  val  test
# Medium       5445  717   769
# Easy         4522  472   588
# Hard         1595  157    82
# Extra Hard   1236   39   104
